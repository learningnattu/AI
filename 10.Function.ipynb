# %%
list =[17 , 30 , 45 ,50 ,85]
def AgeCal():
    for age in list:
        if(age<18):
            print("Children")
        elif(age<40):
            print("Adult")
        elif(age<60):
            print("Citizen")
        else:
            print("Senior Citizen")
    


AgeCal()
# Out:
# Children
# Adult
# Citizen
# Citizen
# Senior Citizen

# %%
age = int(input("Enter age : "))
def AgeCal():
        if(age<18):
            print("Children")
            cate="Children"
        elif(age<40):
            print("Adult")
            cate="Adult"
        elif(age<60):
            print("Citizen")
            cate="Citizen"
        else:
            print("Senior Citizen")
            cate="Senior Citizen"            
        return cate
person1=AgeCal()
